# %% [markdown]
# <a href="https://colab.research.google.com/github/krackofficer/feature-engineering-assignment-/blob/main/feature_engineering_assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Q1. What is a parameter?
# A parameter is an internal variable of a machine learning model that is learned from the training data.
# For example, in linear regression, weights and bias are parameters.

# %%
# Q2. What is correlation?
# Correlation measures the relationship between two variables.
# What does negative correlation mean?
# Negative correlation means that as one variable increases, the other decreases.

# %%
# Q3. Define Machine Learning. What are the main components in Machine Learning?
# Machine Learning is a field of AI that enables systems to learn from data.
# Main components: Data, Model, Loss Function, Optimizer, and Evaluation Metric.

# %%
# Q4. How does loss value help in determining whether the model is good or not?
# Lower loss indicates a better model performance. It measures the error between predicted and actual values.

# %%
# Q5. What are continuous and categorical variables?
# Continuous: Numerical data (e.g., height, weight). Categorical: Categories or labels (e.g., gender, color).

# %%
# Q6. How do we handle categorical variables in Machine Learning? What are the common techniques?
# Techniques: Label Encoding, One-Hot Encoding, Binary Encoding.

# %%
# Q7. What do you mean by training and testing a dataset?
# Training data is used to train the model. Testing data evaluates model performance on unseen data.

# %%
# Q8. What is sklearn.preprocessing?
# It is a module in Scikit-learn used for data preprocessing like scaling, encoding, and normalization.

# %%
# Q9. What is a Test set?
# A portion of the dataset used only to assess the final model performance.

# %%
# Q10. How do we split data for model fitting (training and testing) in Python?
# Using train_test_split from sklearn.model_selection:
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
# Q11. Why do we have to perform EDA before fitting a model to the data?
# EDA helps understand data distribution, detect anomalies, and choose proper preprocessing steps.

# %%
# Q12. What is correlation?
# Already answered in Q2.

# %%
# Q13. What does negative correlation mean?
# Already answered in Q2.

# %%
# Q14. How can you find correlation between variables in Python?
# Using pandas:
import pandas as pd
data = pd.DataFrame(...)
correlation_matrix = data.corr()

# %%
# Q15. What is causation? Explain difference between correlation and causation with an example.
# Causation implies one variable directly affects another. Correlation shows relationship but not cause.
# Example: Ice cream sales and drowning deaths are correlated but not causal.

# %%
# Q16. What is an Optimizer? What are different types of optimizers? Explain each with an example.
# Optimizer updates model parameters to minimize loss.
# Types: SGD, Adam, RMSprop
# Example using Adam: optimizer = torch.optim.Adam(model.parameters(), lr=0.001)

# %%
# Q17. What is sklearn.linear_model?
# A module in sklearn that provides linear models like LinearRegression, LogisticRegression, etc.

# %%
# Q18. What does model.fit() do? What arguments must be given?
# Trains the model on training data. Arguments: training data (X) and labels (y).
# Example: model.fit(X_train, y_train)

# %%
# Q19. What does model.predict() do? What arguments must be given?
# Makes predictions on new data. Argument: input data X.
# Example: predictions = model.predict(X_test)

# %%
# Q20. What are continuous and categorical variables?
# Already answered in Q5.

# %%
# Q21. What is feature scaling? How does it help in Machine Learning?
# Feature scaling standardizes data to a common scale. Helps gradient descent converge faster.

# %%
# Q22. How do we perform scaling in Python?
# Using StandardScaler:
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
# Q23. What is sklearn.preprocessing?
# Already answered in Q8.

# %%
# Q24. How do we split data for model fitting (training and testing) in Python?
# Already answered in Q10.

# %%
# Q25. Explain data encoding?
# Data encoding transforms categorical data into numeric format.
# Methods: Label Encoding, One-Hot Encoding.
